# %%
pip install jupyter_contrib_nbextensions && jupyter contrib nbextensions install
# Out:
# ...
# [I 21:27:14 InstallContribNbextensionsApp] jupyter contrib nbextension install
# ...
# [I 21:27:14 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 21:27:14 InstallContribNbextensionsApp] Installing c:\users\lucas\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore -> addbefore
# [I 21:27:14 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\addbefore.yaml
# [I 21:27:14 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\icon.png
# [I 21:27:14 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\main.js
# [I 21:27:14 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\readme.md
# [I 21:27:14 InstallContribNbextensionsApp] - Validating: ok
# ...

# %%
# !pip install autopep8
